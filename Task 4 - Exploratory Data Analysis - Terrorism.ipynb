# %% [markdown]
# # Task 4 - Exploratory Data Analysis - Terrorism

# %% [markdown]
# ## THE SPARKS FOUNDATION
# ### GRADUATE ROTATIONAL INTERNSHIP PROGRAM GRIPMAR21
# ### DATA SCIENCE AND BUSINESS ANALYTICS
#
#
# ### Author: Abdullah Ficici

# %% [markdown]
# **Business context.** As a security/defense analyst, try to find out the hot zone of terrorism.
#
# **Problem statement.** What all security issues and insights you can derive by EDA?
#
# **Analytical context.** Exploratory Data Analysis.

# %% [markdown]
# ### Import the Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

# %%
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Read The Data

# %%
df = pd.read_csv('globalterrorismdb_0718dist.csv')
df
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       197000000001   1970       7     2        NaN         0        NaN
# 1       197000000002   1970       0     0        NaN         0        NaN
# 2       197001000001   1970       1     0        NaN         0        NaN
# 3       197001000002   1970       1     0        NaN         0        NaN
# 4       197001000003   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country         country_txt  region  ... addnotes  \
# ...

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
pd.DataFrame(df.isnull().sum())
# Out:
#                  0
# eventid          0
# iyear            0
# imonth           0
# iday             0
# approxdate  172452
# ...            ...
# INT_LOG          0
# INT_IDEO         0
# INT_MISC         0
# INT_ANY          0
# related     156653
#
# [135 rows x 1 columns]

# %% [markdown]
# ### Find the Missing Values and Drop the Columns

# %%
print('Number of missing values in the "approxdate" column: ', df['approxdate'].isnull().sum())
# Out:
# Number of missing values in the "approxdate" column:  172452

# %%
print('Number of missing values in the "related" column: ', df['related'].isnull().sum())
# Out:
# Number of missing values in the "related" column:  156653

# %%
df.drop(columns=['approxdate', 'related'], inplace=True)

# %%
pd.DataFrame(df.columns)
# Out:
#             0
# 0     eventid
# 1       iyear
# 2      imonth
# 3        iday
# 4    extended
# ..        ...
# 128  dbsource
# 129   INT_LOG
# 130  INT_IDEO
# 131  INT_MISC
# 132   INT_ANY
#
# [133 rows x 1 columns]

# %%
label_encoder = LabelEncoder()
df.iloc[:,0] = label_encoder.fit_transform(df.iloc[:,0]).astype('float64')

# %% [markdown]
# ### Correlation

# %%
corr = df.corr()
corr
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.955888  0.034361  0.025062  0.092043 -0.107862
# iyear      0.955888  1.000000  0.000139  0.018254  0.091754 -0.135023
# imonth     0.034361  0.000139  1.000000  0.005497 -0.000468 -0.006305
# iday       0.025062  0.018254  0.005497  1.000000 -0.004700  0.003468
# extended   0.092043  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.157749 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.098703 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.087317 -0.133253 -0.002034 -0.001621  0.075147  0.067564
# INT_MISC  -0.066077 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.129521 -0.175596 -0.006336 -0.001199  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.subplots(figsize=(15,10))
sns.heatmap(corr, cmap='seismic') 
plt.show()

# %% [markdown]
# ### Where are the Hot Zones - Top 10 Countries?

# %%
df['country_txt'].value_counts().head(10)
# Out:
# Iraq              24636
# Pakistan          14368
# Afghanistan       12731
# India             11960
# Colombia           8306
# Philippines        6908
# Peru               6096
# El Salvador        5320
# United Kingdom     5235
# Turkey             4292
# Name: country_txt, dtype: int64

# %%
df['country_txt'].value_counts()
plt.figure(figsize=(10,8))
sns.barplot(x=df['country_txt'].value_counts()[:20].index,y=df['country_txt'].value_counts()[:20].values)
plt.title('Hot Zones - Countries')
plt.xticks(rotation=90)
plt.xlabel('Countries')
plt.ylabel('No. of Attacks')
plt.show()

# %% [markdown]
# ### Where are the Safe Zones - Top 10 Countries?

# %%
df['country_txt'].value_counts().tail(10)
# Out:
# Falkland Islands       1
# St. Lucia              1
# International          1
# Wallis and Futuna      1
# New Hebrides           1
# Andorra                1
# North Korea            1
# Antigua and Barbuda    1
# South Vietnam          1
# Vatican City           1
# Name: country_txt, dtype: int64

# %% [markdown]
# ### Where are the Hot Zones - Region?

# %%
df['region_txt'].value_counts()
plt.figure(figsize=(10,8))
sns.countplot(x='region_txt',data=df)
plt.xticks(rotation=90)
plt.show()

# %%
df['region_txt'].value_counts().idxmax()
# Out:
# 'Middle East & North Africa'

# %% [markdown]
# ### Where are the Safe Zones - Region?

# %%
df['region_txt'].value_counts().idxmin()
# Out:
# 'Australasia & Oceania'

# %% [markdown]
# ### Where are the Hot Zones - Cities?

# %%
df['city'].value_counts()
# Out:
# Unknown                   9775
# Baghdad                   7589
# Karachi                   2652
# Lima                      2359
# Mosul                     2265
#                           ...
# Wii-Anaka                    1
# Malar                        1
# Kalapo                       1
# Ancona                       1
# Abu al Khasib district       1
# Name: city, Length: 36674, dtype: int64

# %%
df= df[df['city'] != 'Unknown']

# %%
df['city'].value_counts()
plt.figure(figsize=(10,8))
sns.barplot(x=df['city'].value_counts()[:20].index,y=df['city'].value_counts()[:20].values)
plt.title('Hot Zones - Cities')
plt.xticks(rotation=90)
plt.xlabel('Cities')
plt.ylabel('No of Attacks')
plt.show()

# %% [markdown]
# ### Terror Attacks 1970 - 2017

# %%
plt.subplots(figsize=(14,10))
sns.countplot(x='iyear',data=df,palette='tab10')
plt.xticks(rotation=90)
plt.title('Terror Attacks 1970 - 2017')
plt.xlabel('Year')
plt.show()

# %% [markdown]
# ### Number of Attacks vs. Attack Type

# %%
plt.figure(figsize=(10,8))
sns.countplot(x=df['attacktype1_txt'],order=df['attacktype1_txt'].value_counts().index,palette='tab10')
plt.xticks(rotation=90)
plt.xlabel('Attack Type')
plt.ylabel('Number of Attacks')
plt.show()

# %%
df = df[df['latitude'].notna()]
df = df[df['longitude'].notna()]
df
# Out:
#          eventid  iyear  imonth  iday  extended resolution  country  \
# 0            0.0   1970       7     2         0        NaN       58
# 1            1.0   1970       0     0         0        NaN      130
# 3            3.0   1970       1     0         0        NaN       78
# 4            4.0   1970       1     0         0        NaN      101
# 5            5.0   1970       1     1         0        NaN      217
# ...          ...    ...     ...   ...       ...        ...      ...
# 181686  181686.0   2017      12    31         0        NaN      182
# 181687  181687.0   2017      12    31         0        NaN      200
# 181688  181688.0   2017      12    31         0        NaN      160
# 181689  181689.0   2017      12    31         0        NaN       92
# 181690  181690.0   2017      12    31         0        NaN      160
#
#                country_txt  region                   region_txt  ...  \
# 0       Dominican Republic       2  Central America & Caribbean  ...
# ...
